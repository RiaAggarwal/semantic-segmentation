# %%
from torchvision import utils
from basic_fcn import *
from unet import *
from dataloader import *
from utils import *
import torchvision
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import time
from matplotlib import pyplot as plt
import os
from pprint import pprint

# %%
train_dataset = CityScapesDataset(csv_file='./Data/train.csv')
val_dataset = CityScapesDataset(csv_file='./Data/val.csv')
test_dataset = CityScapesDataset(csv_file='./Data/test.csv')

_batch_size = 4
_num_workers = 4
iou_classes = [11, 20, 24, 26, 33]

train_loader = DataLoader(dataset=train_dataset,
                          batch_size=_batch_size,
                          num_workers=_num_workers,
                          shuffle=True)
val_loader = DataLoader(dataset=val_dataset,
                          batch_size=_batch_size,
                          num_workers=_num_workers,
                          shuffle=True)
test_loader = DataLoader(dataset=test_dataset,
                          batch_size=1,
                          num_workers=_num_workers,
                          shuffle=True)

# %%
def init_weights(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
        torch.nn.init.xavier_uniform_(m.weight.data)
        #torch.nn.init.xavier_uniform(m.bias.data)
        m.bias.data.zero_()
        
epochs     = 200
criterion = nn.CrossEntropyLoss()# Choose an appropriate loss function from https://pytorch.org/docs/stable/_modules/torch/nn/modules/loss.html
unet_model = Unet(n_class=n_class)
    
unet_model.apply(init_weights)
#fcn_model = torch.load('best_model')

optimizer = optim.Adam(unet_model.parameters(), lr=5e-3)

# %%
modelName = 'unet_test'
MYDIR = "./Results" + "/" + modelName
CHECK_FOLDER = os.path.isdir(MYDIR)
if not CHECK_FOLDER:
    os.makedirs(MYDIR)
    print("created folder : ", MYDIR)
else:
    print(MYDIR, "folder already exists.")

def plotTwoGraphs(base, train_metrics, val_metrics):
    plt.figure()
    plt.plot(base, train_metrics)
    plt.plot(base, val_metrics)
    plt.gca().legend(('train','validation'))
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss vs Epochs')
    plt.savefig(MYDIR + '/loss.png')

def plotGraph(base, metrics, name):
    plt.figure()
    plt.plot(base, metrics)
    plt.xlabel('Epochs')
    plt.ylabel(name)
    plt.title(name + ' vs Epochs')
    plt.savefig(MYDIR + '/' + name + '.png')
# Out:
# ./Results/unet_test folder already exists.

# %%
use_gpu = torch.cuda.is_available()
if use_gpu:
    unet_model = unet_model.cuda()
    
all_train_losses = []
all_val_losses = []
all_val_accuracies = []
all_val_iou = []
all_val_iou_class = {}


        
def train():
    startingValLoss = 10000000.0
    for epoch in range(epochs):
        unet_model.train()
        curEpochLoss = []
        ts = time.time()
        for iter, (X, tar, Y) in enumerate(train_loader):
            optimizer.zero_grad()

            if use_gpu:
                inputs = X.cuda()   # Move your inputs onto the gpu
                labels = Y.cuda() # Move your labels onto the gpu
            else:
                inputs, labels = X, Y# Unpack variables into inputs and labels
            outputs = unet_model(inputs)
            loss = criterion(outputs, labels)
            curEpochLoss.append(loss.item())
            loss.backward()
            optimizer.step()

            if iter % 100 == 0:
                print("epoch{}, iter{}, loss: {}".format(epoch, iter, loss.item(), time.time() - ts))
        curEpochLoss = sum(curEpochLoss)/len(curEpochLoss)
        print('training loss : ', curEpochLoss)
        all_train_losses.append(curEpochLoss)
        print("Finish epoch {}, time elapsed {}".format(epoch, time.time() - ts))
        
        
        val_loss, val_accuracy, val_iou_net, val_iou_net_class_wise = val(epoch)
        all_val_losses.append(val_loss)
        all_val_accuracies.append(val_accuracy)
        all_val_iou.append(val_iou_net)
        for c in val_iou_net_class_wise:
            if(c not in all_val_iou_class):
                all_val_iou_class[c] = []
            all_val_iou_class[c].append(val_iou_net_class_wise[c])
        
        plotTwoGraphs([i for i in range(epoch+1)], all_train_losses, all_val_losses)
        plotGraph([i for i in range(epoch+1)], all_val_accuracies, 'validation_accuracy')
        plotGraph([i for i in range(epoch+1)], all_val_iou, 'average_iou')
        for c in all_val_iou_class:
            plotGraph([i for i in range(epoch+1)], all_val_iou_class[c], 'iou'+str(c))
        
        if(val_loss < startingValLoss):
            startingValLoss = val_loss
            results = {}
            results['accuracy'] = val_accuracy
            results['iou_net'] = val_iou_net
            results['iou_net_class_wise'] = val_iou_net_class_wise
            results['total_loss'] = val_loss
            results['epoch'] = epoch
            with open(MYDIR + '/results_val.txt', 'wt') as out:
                pprint(results, stream=out)
            torch.save(unet_model, MYDIR + '/best_model')
            #test(epoch)
    


def val(epoch):
    unet_model.eval()
    #Complete this function - Calculate loss, accuracy and IoU for every epoch
    # Make sure to include a softmax after the output from your model
    total_loss = []
    acc_num = 0
    acc_den = 0
    #iou_num = len(iou_classes)*[0] 
    #iou_den = len(iou_classes)*[0] 
    iou_num = {}
    iou_den = {}
    
    for iter, (X_val, tar_val, Y_val) in enumerate(val_loader):
        if use_gpu:
            inputs_val = X_val.cuda()   # Move your inputs onto the gpu
            labels_val = Y_val.cuda() # Move your labels onto the gpu
        else:
            inputs_val, labels_val = X_val, Y_val# Unpack variables into inputs and labels

        outputs_val = unet_model(inputs_val)
        
        _, preds = torch.max(outputs_val, 1)
        
        loss_val = criterion(outputs_val, labels_val).item()
        
        preds_cpu = preds.cpu()
        Y_cpu = Y_val.cpu()
        
        total_loss.append(loss_val)
        
        nn, dd = pixel_acc(preds_cpu, Y_cpu)
        acc_num += nn
        acc_den += dd
        
        for iou_cc_idx in range(len(iou_classes)):
            i_nn, i_dd = iou(preds_cpu, Y_cpu, iou_classes[iou_cc_idx])
            if iou_cc_idx not in iou_num:
                iou_num[iou_cc_idx] = 0
                iou_den[iou_cc_idx] = 0
            iou_num[iou_cc_idx] += i_nn
            iou_den[iou_cc_idx] += i_dd
            
        del inputs_val
        del labels_val
        del loss_val
    total_loss = sum(total_loss)/len(total_loss)
    print("Validation loss after epoch {}, , loss: {}".format(epoch, total_loss))
    print("Accuracy on val after epoch {}, accuracy: {}".format(epoch, 100*acc_num/acc_den))
    for iou_cc_idx in range(len(iou_classes)):
        print("IOU for class {} on val after epoch{}, iou: {}".format(iou_classes[iou_cc_idx], epoch, 100*iou_num[iou_cc_idx]/iou_den[iou_cc_idx]))

    iou_net_class_wise = dict((c, iou_num[c]/iou_den[c]) for c in iou_num)
    accuracy = acc_num / acc_den
    iou_net_num = 0
    iou_net_den = 0
    for c in iou_num:
        iou_net_num += iou_num[c]
        iou_net_den += iou_den[c]
    iou_net = iou_net_num/iou_net_den

    return total_loss, accuracy, iou_net, iou_net_class_wise

def colorMap(a, i):
    return idsColor[a][i]

def test(numFigures):
    #fcn_model.load_state_dict(torch.load(MYDIR + '/best_model'))
    model = torch.load(MYDIR + '/best_model')
    model.cuda()
    model.eval()
    dataiter = iter(test_loader)
    i = 0
    while(i < numFigures):
        i += 1
        X_test, img_full, Y_test = dataiter.next()
        if use_gpu:
            inputs_test = X_test.cuda()   # Move your inputs onto the gpu
            labels_test = Y_test.cuda() # Move your labels onto the gpu
            #img_full_test = img_full.cuda()
        else:
            inputs_test, labels_test = X_test, Y_test# Unpack variables into inputs and labels
            #img_full_test = img_full

        outputs = model(inputs_test)
        _, preds = torch.max(outputs, 1)
        inputs_test = inputs_test.permute(0, 2, 3, 1)
        #img_full_test = img_full_test.permute(0, 2, 3, 1)

        f = plt.figure(figsize=(16,8))
        ax = f.add_subplot(121)
        ax2 = f.add_subplot(122)

        #plt.subplot(1, 2, 1)
        ax.imshow(torchvision.utils.make_grid(-1*inputs_test.cpu()))


        preds = preds.cpu().numpy()

        preds0 = np.vectorize(colorMap)(preds, 0)
        preds1 = np.vectorize(colorMap)(preds, 1)
        preds2 = np.vectorize(colorMap)(preds, 2)

        preds = torch.from_numpy(np.transpose(np.concatenate((preds0, preds1, preds2), 0), (1,2,0)))

        #plt.subplot(1, 2, 2)
        ax2.imshow(torchvision.utils.make_grid(preds.cpu()))
        
    
if __name__ == "__main__":
    #test(10)
    train()
# Out:
# epoch0, iter0, loss: 4.081492900848389
# epoch0, iter100, loss: 2.0944466590881348
# epoch0, iter200, loss: 2.2188498973846436
# epoch0, iter300, loss: 1.779818058013916
# epoch0, iter400, loss: 1.595750331878662
# epoch0, iter500, loss: 1.199023962020874
# epoch0, iter600, loss: 2.11834979057312
# epoch0, iter700, loss: 1.6761348247528076
# training loss :  1.8260249934529746
# Finish epoch 0, time elapsed 169.2627830505371
# Validation loss after epoch 0, , loss: 1.4780387501716614
# Accuracy on val after epoch 0, accuracy: 63.59333202060975
# IOU for class 11 on val after epoch0, iou: 33.545494565236304
# IOU for class 20 on val after epoch0, iou: 0.0
# IOU for class 24 on val after epoch0, iou: 0.0
# IOU for class 26 on val after epoch0, iou: 9.050692632281564
# IOU for class 33 on val after epoch0, iou: 0.0
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Unet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type BatchNorm2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type MaxPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ReLU. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ConvTranspose2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# epoch1, iter0, loss: 2.38748836517334
# epoch1, iter100, loss: 1.7992254495620728
# epoch1, iter200, loss: 1.3053669929504395
# epoch1, iter300, loss: 1.4601860046386719
# epoch1, iter400, loss: 2.062434434890747
# epoch1, iter500, loss: 0.8591049909591675
# epoch1, iter600, loss: 1.4901260137557983
# epoch1, iter700, loss: 1.8906562328338623
# training loss :  1.5729828686002763
# Finish epoch 1, time elapsed 170.83172488212585
# Validation loss after epoch 1, , loss: 1.5352466065883636
# Accuracy on val after epoch 1, accuracy: 64.25957656037188
# IOU for class 11 on val after epoch1, iou: 31.821126464383347
# IOU for class 20 on val after epoch1, iou: 2.7644518914738674
# IOU for class 24 on val after epoch1, iou: 0.0
# IOU for class 26 on val after epoch1, iou: 16.468974359560487
# IOU for class 33 on val after epoch1, iou: 0.0
# epoch2, iter0, loss: 1.73259437084198
# epoch2, iter100, loss: 1.53183913230896
# epoch2, iter200, loss: 1.6283568143844604
# epoch2, iter300, loss: 1.3882298469543457
# epoch2, iter400, loss: 0.9576632380485535
# epoch2, iter500, loss: 1.377685546875
# epoch2, iter600, loss: 1.0215970277786255
# epoch2, iter700, loss: 2.257150888442993
# training loss :  1.5130593855214376
# Finish epoch 2, time elapsed 171.00116443634033
# Validation loss after epoch 2, , loss: 1.291984179019928
# Accuracy on val after epoch 2, accuracy: 70.77832117687782
# IOU for class 11 on val after epoch2, iou: 37.31167972523755
# IOU for class 20 on val after epoch2, iou: 5.127218843258537
# IOU for class 24 on val after epoch2, iou: 0.0
# IOU for class 26 on val after epoch2, iou: 7.1016113515132275
# IOU for class 33 on val after epoch2, iou: 0.0
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# epoch3, iter0, loss: 1.1240882873535156
# epoch3, iter100, loss: 1.8242173194885254
# epoch3, iter200, loss: 1.055253267288208
# epoch3, iter300, loss: 1.2855017185211182
# epoch3, iter400, loss: 0.9017537236213684
# epoch3, iter500, loss: 0.9804880619049072
# epoch3, iter600, loss: 1.4695030450820923
# epoch3, iter700, loss: 1.260101079940796
# training loss :  1.465376484658449
# Finish epoch 3, time elapsed 171.168518781662
# Validation loss after epoch 3, , loss: 1.3309197087287903
# Accuracy on val after epoch 3, accuracy: 69.45245656361679
# IOU for class 11 on val after epoch3, iou: 42.72280361578731
# IOU for class 20 on val after epoch3, iou: 5.198948228898916
# IOU for class 24 on val after epoch3, iou: 1.514592878499966
# IOU for class 26 on val after epoch3, iou: 18.802462874077662
# IOU for class 33 on val after epoch3, iou: 0.0
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   # This is added back by InteractiveShellApp.init_path()
# epoch4, iter0, loss: 1.3482089042663574
# epoch4, iter100, loss: 1.6923010349273682
# epoch4, iter200, loss: 1.5227125883102417
# epoch4, iter300, loss: 1.7618281841278076
# epoch4, iter400, loss: 0.66685551404953
# epoch4, iter500, loss: 0.9891368746757507
# epoch4, iter600, loss: 1.3625450134277344
# epoch4, iter700, loss: 1.874997615814209
# training loss :  1.4037151485681534
# Finish epoch 4, time elapsed 171.40306568145752
# Validation loss after epoch 4, , loss: 1.2890182123184204
# Accuracy on val after epoch 4, accuracy: 71.12674156029578
# IOU for class 11 on val after epoch4, iou: 46.341004323687905
# IOU for class 20 on val after epoch4, iou: 3.9969166262129447
# IOU for class 24 on val after epoch4, iou: 3.661523704460474
# IOU for class 26 on val after epoch4, iou: 23.23316462386716
# IOU for class 33 on val after epoch4, iou: 0.0
# epoch5, iter0, loss: 1.032326340675354
# epoch5, iter100, loss: 0.8852105736732483
# epoch5, iter200, loss: 1.6554343700408936
# epoch5, iter300, loss: 1.5482892990112305
# epoch5, iter400, loss: 1.0028384923934937
# epoch5, iter500, loss: 1.0271974802017212
# epoch5, iter600, loss: 1.2266149520874023
# epoch5, iter700, loss: 1.1888952255249023
# training loss :  1.3710657466323144
# Finish epoch 5, time elapsed 171.3916974067688
# Validation loss after epoch 5, , loss: 1.3818230516910552
# Accuracy on val after epoch 5, accuracy: 68.67675439578326
# IOU for class 11 on val after epoch5, iou: 45.39409531535675
# IOU for class 20 on val after epoch5, iou: 1.088663697583855
# IOU for class 24 on val after epoch5, iou: 0.05271861327517764
# IOU for class 26 on val after epoch5, iou: 9.617890014611287
# IOU for class 33 on val after epoch5, iou: 0.0
# epoch6, iter0, loss: 1.075319528579712
# epoch6, iter100, loss: 1.3187915086746216
# epoch6, iter200, loss: 0.9670792818069458
# epoch6, iter300, loss: 1.1962218284606934
# epoch6, iter400, loss: 1.2335989475250244
# epoch6, iter500, loss: 0.8333638310432434
# epoch6, iter600, loss: 1.1806119680404663
# epoch6, iter700, loss: 0.8554189205169678
# training loss :  1.3425801092738747
# Finish epoch 6, time elapsed 170.76336789131165
# Validation loss after epoch 6, , loss: 1.1921805410385131
# Accuracy on val after epoch 6, accuracy: 73.29589640432253
# IOU for class 11 on val after epoch6, iou: 50.10943860753465
# IOU for class 20 on val after epoch6, iou: 8.269727059424016
# IOU for class 24 on val after epoch6, iou: 0.7464680355425652
# IOU for class 26 on val after epoch6, iou: 14.204426510642591
# IOU for class 33 on val after epoch6, iou: 0.0
# epoch7, iter0, loss: 1.5456206798553467
# epoch7, iter100, loss: 0.9815635085105896
# epoch7, iter200, loss: 1.4404655694961548
# epoch7, iter300, loss: 1.14558744430542
# epoch7, iter400, loss: 1.5001037120819092
# epoch7, iter500, loss: 0.7547685503959656
# epoch7, iter600, loss: 0.9713625311851501
# epoch7, iter700, loss: 1.5556851625442505
# training loss :  1.3230178482349841
# Finish epoch 7, time elapsed 171.1375012397766
# Validation loss after epoch 7, , loss: 1.186040458917618
# Accuracy on val after epoch 7, accuracy: 74.31088819298084
# IOU for class 11 on val after epoch7, iou: 47.746043671056235
# IOU for class 20 on val after epoch7, iou: 3.802609696814635
# IOU for class 24 on val after epoch7, iou: 0.23091648131015885
# IOU for class 26 on val after epoch7, iou: 24.314880362692083
# IOU for class 33 on val after epoch7, iou: 0.0
# epoch8, iter0, loss: 0.953930139541626
# epoch8, iter100, loss: 1.9286015033721924
# epoch8, iter200, loss: 1.4050955772399902
# epoch8, iter300, loss: 0.8250200152397156
# epoch8, iter400, loss: 1.1788631677627563
# epoch8, iter500, loss: 0.9259439706802368
# epoch8, iter600, loss: 0.9803850054740906
# epoch8, iter700, loss: 1.5738650560379028
# training loss :  1.3061884834721524
# Finish epoch 8, time elapsed 171.14980268478394
# Validation loss after epoch 8, , loss: 1.2355587396621703
# Accuracy on val after epoch 8, accuracy: 71.68695571113635
# IOU for class 11 on val after epoch8, iou: 45.81752036280063
# IOU for class 20 on val after epoch8, iou: 3.637870281892021
# IOU for class 24 on val after epoch8, iou: 1.0371772901948515
# IOU for class 26 on val after epoch8, iou: 26.036045926970704
# IOU for class 33 on val after epoch8, iou: 0.0
# epoch9, iter0, loss: 0.8972373008728027
# epoch9, iter100, loss: 1.1532526016235352
# epoch9, iter200, loss: 1.1954739093780518
# epoch9, iter300, loss: 0.7842856645584106
# epoch9, iter400, loss: 0.9104143381118774
# epoch9, iter500, loss: 0.9139857888221741
# epoch9, iter600, loss: 1.1720058917999268
# epoch9, iter700, loss: 0.8885279893875122
# training loss :  1.274245263588044
# Finish epoch 9, time elapsed 170.95819687843323
# Validation loss after epoch 9, , loss: 1.2042794513702393
# Accuracy on val after epoch 9, accuracy: 73.27081943519045
# IOU for class 11 on val after epoch9, iou: 50.06446800745247
# IOU for class 20 on val after epoch9, iou: 4.086325708935944
# IOU for class 24 on val after epoch9, iou: 0.0008698861567559709
# IOU for class 26 on val after epoch9, iou: 21.169723474796175
# IOU for class 33 on val after epoch9, iou: 0.0
# epoch10, iter0, loss: 0.7668037414550781
# epoch10, iter100, loss: 0.8287582397460938
# epoch10, iter200, loss: 0.6680868268013
# epoch10, iter300, loss: 1.0713645219802856
# epoch10, iter400, loss: 1.0453927516937256
# epoch10, iter500, loss: 0.7123835682868958
# epoch10, iter600, loss: 1.6754601001739502
# epoch10, iter700, loss: 1.3236883878707886
# training loss :  1.2291077749943862
# Finish epoch 10, time elapsed 171.31570172309875
# Validation loss after epoch 10, , loss: 1.160119649529457
# Accuracy on val after epoch 10, accuracy: 75.72402947997901
# IOU for class 11 on val after epoch10, iou: 52.949708025583405
# IOU for class 20 on val after epoch10, iou: 10.272272843065638
# IOU for class 24 on val after epoch10, iou: 5.1141661707756105
# IOU for class 26 on val after epoch10, iou: 29.3484303147532
# IOU for class 33 on val after epoch10, iou: 0.004241526666831615
# epoch11, iter0, loss: 0.9346581697463989
# epoch11, iter100, loss: 1.2056692838668823
# epoch11, iter200, loss: 1.260607361793518
# epoch11, iter300, loss: 0.8861861228942871
# epoch11, iter400, loss: 0.5805010199546814
# epoch11, iter500, loss: 0.3778741657733917
# epoch11, iter600, loss: 2.1146278381347656
# epoch11, iter700, loss: 1.7663300037384033
# training loss :  1.2035003255211538
# Finish epoch 11, time elapsed 171.7111566066742
# Validation loss after epoch 11, , loss: 1.0771473422050477
# Accuracy on val after epoch 11, accuracy: 76.47715998989517
# IOU for class 11 on val after epoch11, iou: 53.450122768329365
# IOU for class 20 on val after epoch11, iou: 5.628745774790781
# IOU for class 24 on val after epoch11, iou: 0.20516539505054412
# IOU for class 26 on val after epoch11, iou: 27.183518288093715
# IOU for class 33 on val after epoch11, iou: 0.0
# epoch12, iter0, loss: 1.3456720113754272
# epoch12, iter100, loss: 1.2932798862457275
# epoch12, iter200, loss: 1.2029346227645874
# epoch12, iter300, loss: 0.9880776405334473
# epoch12, iter400, loss: 0.4402509927749634
# epoch12, iter500, loss: 0.7940430641174316
# epoch12, iter600, loss: 1.3388803005218506
# epoch12, iter700, loss: 1.3311080932617188
# training loss :  1.2000529744051478
# Finish epoch 12, time elapsed 171.21623611450195
# Validation loss after epoch 12, , loss: 1.1921263644695281
# Accuracy on val after epoch 12, accuracy: 73.31775046892227
# IOU for class 11 on val after epoch12, iou: 53.277965641325025
# IOU for class 20 on val after epoch12, iou: 7.463708277513745
# IOU for class 24 on val after epoch12, iou: 1.1501968700042857
# IOU for class 26 on val after epoch12, iou: 20.083406634447773
# IOU for class 33 on val after epoch12, iou: 0.0
# epoch13, iter0, loss: 1.5729552507400513
# epoch13, iter100, loss: 0.9844252467155457
# epoch13, iter200, loss: 0.8191171884536743
# epoch13, iter300, loss: 1.129173755645752
# epoch13, iter400, loss: 0.8512556552886963
# epoch13, iter500, loss: 0.8399177193641663
# epoch13, iter600, loss: 0.9642490148544312
# epoch13, iter700, loss: 1.2688833475112915
# training loss :  1.166208607735493
# Finish epoch 13, time elapsed 171.22741961479187
# Validation loss after epoch 13, , loss: 1.1780580849647522
# Accuracy on val after epoch 13, accuracy: 73.93887280808646
# IOU for class 11 on val after epoch13, iou: 52.67458415350633
# IOU for class 20 on val after epoch13, iou: 9.24072984108299
# IOU for class 24 on val after epoch13, iou: 1.1676070407975023
# IOU for class 26 on val after epoch13, iou: 27.191448447632283
# IOU for class 33 on val after epoch13, iou: 0.004097056867149316
# epoch14, iter0, loss: 0.9511656165122986
# epoch14, iter100, loss: 1.1408525705337524
# epoch14, iter200, loss: 1.1535533666610718
# epoch14, iter300, loss: 1.5981515645980835
# epoch14, iter400, loss: 0.5084760189056396
# epoch14, iter500, loss: 0.6437076330184937
# epoch14, iter600, loss: 0.6471109390258789
# epoch14, iter700, loss: 2.2500033378601074
# training loss :  1.1436927441147067
# Finish epoch 14, time elapsed 171.0954623222351
# Validation loss after epoch 14, , loss: 1.178815882921219
# Accuracy on val after epoch 14, accuracy: 71.74905865682413
# IOU for class 11 on val after epoch14, iou: 47.463610743747694
# IOU for class 20 on val after epoch14, iou: 7.652082256686298
# IOU for class 24 on val after epoch14, iou: 0.9676417400782421
# IOU for class 26 on val after epoch14, iou: 20.677427509262444
# IOU for class 33 on val after epoch14, iou: 0.0
# epoch15, iter0, loss: 0.8663854598999023
# epoch15, iter100, loss: 0.68011873960495
# epoch15, iter200, loss: 0.7326658368110657
# epoch15, iter300, loss: 1.6086523532867432
# epoch15, iter400, loss: 0.8655229210853577
# epoch15, iter500, loss: 0.8202817440032959
# epoch15, iter600, loss: 0.9886956214904785
# epoch15, iter700, loss: 1.5465365648269653
# training loss :  1.1064128103035111
# Finish epoch 15, time elapsed 171.13700079917908
# Validation loss after epoch 15, , loss: 1.1362222002744675
# Accuracy on val after epoch 15, accuracy: 76.25853674087483
# IOU for class 11 on val after epoch15, iou: 51.64057255202839
# IOU for class 20 on val after epoch15, iou: 6.136380121373634
# IOU for class 24 on val after epoch15, iou: 0.2826925978984622
# IOU for class 26 on val after epoch15, iou: 32.347266416530125
# IOU for class 33 on val after epoch15, iou: 0.0023213645496681736
# epoch16, iter0, loss: 0.9500731229782104
# epoch16, iter100, loss: 0.7742578387260437
# epoch16, iter200, loss: 1.0366542339324951
# epoch16, iter300, loss: 1.1303250789642334
# epoch16, iter400, loss: 0.6121947765350342
# epoch16, iter500, loss: 1.1026194095611572
# epoch16, iter600, loss: 1.1320768594741821
# epoch16, iter700, loss: 1.2224750518798828
# training loss :  1.104181255063703
# Finish epoch 16, time elapsed 171.28223872184753
# Validation loss after epoch 16, , loss: 0.9788685644865036
# Accuracy on val after epoch 16, accuracy: 78.7251008008301
# IOU for class 11 on val after epoch16, iou: 55.38937744822732
# IOU for class 20 on val after epoch16, iou: 8.621602059825104
# IOU for class 24 on val after epoch16, iou: 1.6395175085035685
# IOU for class 26 on val after epoch16, iou: 36.04095057798272
# IOU for class 33 on val after epoch16, iou: 0.0
# epoch17, iter0, loss: 1.3089399337768555
# epoch17, iter100, loss: 1.2523362636566162
# epoch17, iter200, loss: 0.9734331965446472
# epoch17, iter300, loss: 0.8816166520118713
# epoch17, iter400, loss: 1.0659643411636353
# epoch17, iter500, loss: 0.7470612525939941
# epoch17, iter600, loss: 0.8592536449432373
# epoch17, iter700, loss: 2.047485589981079
# training loss :  1.0770015097673862
# Finish epoch 17, time elapsed 171.26957511901855
# Validation loss after epoch 17, , loss: 1.0162045228481293
# Accuracy on val after epoch 17, accuracy: 78.72859552736438
# IOU for class 11 on val after epoch17, iou: 55.55396594961144
# IOU for class 20 on val after epoch17, iou: 7.269009546437393
# IOU for class 24 on val after epoch17, iou: 2.0206464806397544
# IOU for class 26 on val after epoch17, iou: 34.774558019426685
# IOU for class 33 on val after epoch17, iou: 0.01030290541932825
# epoch18, iter0, loss: 0.5838037133216858
# epoch18, iter100, loss: 0.8961842656135559
# epoch18, iter200, loss: 1.1709542274475098
# epoch18, iter300, loss: 0.9887034893035889
# epoch18, iter400, loss: 0.8417486548423767
# epoch18, iter500, loss: 0.45415419340133667
# epoch18, iter600, loss: 1.0066405534744263
# epoch18, iter700, loss: 1.4396449327468872
# training loss :  1.0884993625103787
# Finish epoch 18, time elapsed 171.51596593856812
# Validation loss after epoch 18, , loss: 0.9642044209241867
# Accuracy on val after epoch 18, accuracy: 79.53934671489206
# IOU for class 11 on val after epoch18, iou: 59.9232754295962
# IOU for class 20 on val after epoch18, iou: 6.420237261755001
# IOU for class 24 on val after epoch18, iou: 1.965730854750506
# IOU for class 26 on val after epoch18, iou: 41.67789906811799
# IOU for class 33 on val after epoch18, iou: 0.0
# epoch19, iter0, loss: 1.253244400024414
# epoch19, iter100, loss: 1.091762900352478
# epoch19, iter200, loss: 1.1006118059158325
# epoch19, iter300, loss: 1.0222731828689575
# epoch19, iter400, loss: 0.9909571409225464
# epoch19, iter500, loss: 0.611553966999054
# epoch19, iter600, loss: 1.6368751525878906
# epoch19, iter700, loss: 1.3773425817489624
# training loss :  1.0176820795462336
# Finish epoch 19, time elapsed 171.26875591278076
# Validation loss after epoch 19, , loss: 35.81720166063309
# Accuracy on val after epoch 19, accuracy: 76.70050186131787
# IOU for class 11 on val after epoch19, iou: 53.773287494448624
# IOU for class 20 on val after epoch19, iou: 6.9373123029093575
# IOU for class 24 on val after epoch19, iou: 2.2666243012866762
# IOU for class 26 on val after epoch19, iou: 39.568928474357065
# IOU for class 33 on val after epoch19, iou: 0.0007163092880243831
# epoch20, iter0, loss: 0.6488979458808899
# epoch20, iter100, loss: 1.035712480545044
# epoch20, iter200, loss: 1.6097402572631836
# epoch20, iter300, loss: 1.06639564037323
# epoch20, iter400, loss: 0.5983021855354309
# epoch20, iter500, loss: 1.233762264251709
# epoch20, iter600, loss: 0.44964492321014404
# epoch20, iter700, loss: 1.881150484085083
# training loss :  1.065884845912136
# Finish epoch 20, time elapsed 171.1948630809784
# Validation loss after epoch 20, , loss: 0.9992306083440781
# Accuracy on val after epoch 20, accuracy: 78.63518605928172
# IOU for class 11 on val after epoch20, iou: 61.53150260497217
# IOU for class 20 on val after epoch20, iou: 5.451491695471852
# IOU for class 24 on val after epoch20, iou: 14.012060442449952
# IOU for class 26 on val after epoch20, iou: 33.958252166042165
# IOU for class 33 on val after epoch20, iou: 0.0
# epoch21, iter0, loss: 1.045072078704834
# epoch21, iter100, loss: 0.7959173917770386
# epoch21, iter200, loss: 0.48281487822532654
# epoch21, iter300, loss: 0.7549533843994141
# epoch21, iter400, loss: 0.7294195294380188
# epoch21, iter500, loss: 0.6597486138343811
# epoch21, iter600, loss: 1.0994764566421509
# epoch21, iter700, loss: 0.7678592205047607
# training loss :  1.052611477913395
# Finish epoch 21, time elapsed 171.235778093338
# Validation loss after epoch 21, , loss: 3.5385192114114763
# Accuracy on val after epoch 21, accuracy: 76.6430006508633
# IOU for class 11 on val after epoch21, iou: 55.4156918442384
# IOU for class 20 on val after epoch21, iou: 9.446551503837895
# IOU for class 24 on val after epoch21, iou: 1.5143891587460747
# IOU for class 26 on val after epoch21, iou: 32.249011733065664
# IOU for class 33 on val after epoch21, iou: 0.001847906717668892
# epoch22, iter0, loss: 1.5892945528030396
# epoch22, iter100, loss: 1.4600039720535278
# epoch22, iter200, loss: 1.1700812578201294
# epoch22, iter300, loss: 1.1263583898544312
# epoch22, iter400, loss: 0.6743596792221069
# epoch22, iter500, loss: 0.834466278553009
# epoch22, iter600, loss: 0.880016565322876
# epoch22, iter700, loss: 1.2299140691757202
# training loss :  1.0074175168029083
# Finish epoch 22, time elapsed 171.28631615638733
# Validation loss after epoch 22, , loss: 41.04408503711224
# Accuracy on val after epoch 22, accuracy: 80.30393654373528
# IOU for class 11 on val after epoch22, iou: 58.45264903120437
# IOU for class 20 on val after epoch22, iou: 6.188108397086377
# IOU for class 24 on val after epoch22, iou: 0.525284474780697
# IOU for class 26 on val after epoch22, iou: 39.52116474117359
# IOU for class 33 on val after epoch22, iou: 0.0
# epoch23, iter0, loss: 0.7709907293319702
# epoch23, iter100, loss: 0.96401047706604
# epoch23, iter200, loss: 1.1715718507766724
# epoch23, iter300, loss: 1.5443170070648193
# epoch23, iter400, loss: 0.47047853469848633
# epoch23, iter500, loss: 0.6368234157562256
# epoch23, iter600, loss: 0.8987314701080322
# epoch23, iter700, loss: 2.229910373687744
# training loss :  0.9891312476648118
# Finish epoch 23, time elapsed 171.47597455978394
# Validation loss after epoch 23, , loss: 0.9680051593780518
# Accuracy on val after epoch 23, accuracy: 78.52365058384946
# IOU for class 11 on val after epoch23, iou: 55.12490553373318
# IOU for class 20 on val after epoch23, iou: 6.865983042571137
# IOU for class 24 on val after epoch23, iou: 0.7351308772617536
# IOU for class 26 on val after epoch23, iou: 38.735362675508746
# IOU for class 33 on val after epoch23, iou: 0.0
# epoch24, iter0, loss: 0.6169191598892212
# epoch24, iter100, loss: 1.034409999847412
# epoch24, iter200, loss: 1.7847416400909424
# epoch24, iter300, loss: 0.8886474370956421
# epoch24, iter400, loss: 0.6118707060813904
# epoch24, iter500, loss: 0.3559900224208832
# epoch24, iter600, loss: 0.9160225987434387
# epoch24, iter700, loss: 1.818580985069275
# training loss :  0.9679832958806587
# Finish epoch 24, time elapsed 171.30221223831177
# Validation loss after epoch 24, , loss: 0.9377117544412613
# Accuracy on val after epoch 24, accuracy: 80.9256008320052
# IOU for class 11 on val after epoch24, iou: 55.78980725105738
# IOU for class 20 on val after epoch24, iou: 5.909428695528662
# IOU for class 24 on val after epoch24, iou: 5.449211075304417
# IOU for class 26 on val after epoch24, iou: 46.13035155736947
# IOU for class 33 on val after epoch24, iou: 0.0
# epoch25, iter0, loss: 1.0111998319625854
# epoch25, iter100, loss: 1.190350890159607
# epoch25, iter200, loss: 0.3912842571735382
# epoch25, iter300, loss: 1.2315881252288818
# epoch25, iter400, loss: 0.6826307773590088
# epoch25, iter500, loss: 0.5202572345733643
# epoch25, iter600, loss: 0.9014506340026855
# epoch25, iter700, loss: 2.1111245155334473
# training loss :  0.9473797501495449
# Finish epoch 25, time elapsed 171.17829513549805
# Validation loss after epoch 25, , loss: 0.9324640452861785
# Accuracy on val after epoch 25, accuracy: 80.44915233807168
# IOU for class 11 on val after epoch25, iou: 59.74152100110861
# IOU for class 20 on val after epoch25, iou: 3.1313073208064366
# IOU for class 24 on val after epoch25, iou: 1.4192463601608878
# IOU for class 26 on val after epoch25, iou: 40.016231608187894
# IOU for class 33 on val after epoch25, iou: 0.0
# epoch26, iter0, loss: 0.6051877737045288
# epoch26, iter100, loss: 1.2452282905578613
# epoch26, iter200, loss: 1.6545073986053467
# epoch26, iter300, loss: 1.061046838760376
# epoch26, iter400, loss: 0.44036853313446045
# epoch26, iter500, loss: 0.7108711004257202
# epoch26, iter600, loss: 0.4228706657886505
# epoch26, iter700, loss: 0.8782658576965332
# training loss :  0.9550468995366045
# Finish epoch 26, time elapsed 171.63476729393005
# Validation loss after epoch 26, , loss: 0.8845331700444221
# Accuracy on val after epoch 26, accuracy: 81.56205211346608
# IOU for class 11 on val after epoch26, iou: 61.6386883072411
# IOU for class 20 on val after epoch26, iou: 11.83488106960719
# IOU for class 24 on val after epoch26, iou: 15.813496708967573
# IOU for class 26 on val after epoch26, iou: 47.2761842784475
# IOU for class 33 on val after epoch26, iou: 0.0048808300960857965
# epoch27, iter0, loss: 0.7901523113250732
# epoch27, iter100, loss: 0.9900065064430237
# epoch27, iter200, loss: 1.0499975681304932
# epoch27, iter300, loss: 0.684795618057251
# epoch27, iter400, loss: 0.4300397038459778
# epoch27, iter500, loss: 0.3627917766571045
# epoch27, iter600, loss: 0.9821369051933289
# epoch27, iter700, loss: 0.7966495752334595
# training loss :  0.9367744786444531
# Finish epoch 27, time elapsed 171.33217859268188
# Validation loss after epoch 27, , loss: 0.8871291581988334
# Accuracy on val after epoch 27, accuracy: 80.65751883987758
# IOU for class 11 on val after epoch27, iou: 59.030576378115825
# IOU for class 20 on val after epoch27, iou: 17.352253988518306
# IOU for class 24 on val after epoch27, iou: 16.8631274808881
# IOU for class 26 on val after epoch27, iou: 46.98547685897261
# IOU for class 33 on val after epoch27, iou: 0.0026265457818868626
# epoch28, iter0, loss: 0.47405168414115906
# epoch28, iter100, loss: 0.5487880706787109
# epoch28, iter200, loss: 0.7583423852920532
# epoch28, iter300, loss: 1.1657012701034546
# epoch28, iter400, loss: 0.4246746003627777
# epoch28, iter500, loss: 0.388151615858078
# epoch28, iter600, loss: 0.8129849433898926
# epoch28, iter700, loss: 1.2302098274230957
# training loss :  0.9351682986423213
# Finish epoch 28, time elapsed 171.50778222084045
# Validation loss after epoch 28, , loss: 0.9625694978237153
# Accuracy on val after epoch 28, accuracy: 79.8821663087091
# IOU for class 11 on val after epoch28, iou: 58.31435501226949
# IOU for class 20 on val after epoch28, iou: 13.340087305016313
# IOU for class 24 on val after epoch28, iou: 13.9745532890328
# IOU for class 26 on val after epoch28, iou: 43.542976676778174
# IOU for class 33 on val after epoch28, iou: 0.0
# epoch29, iter0, loss: 0.5744582414627075
# epoch29, iter100, loss: 0.5960739254951477
# epoch29, iter200, loss: 1.5142208337783813
# epoch29, iter300, loss: 0.7238042950630188
# epoch29, iter400, loss: 0.4938580393791199
# epoch29, iter500, loss: 0.3499930799007416
# epoch29, iter600, loss: 1.2336078882217407
# epoch29, iter700, loss: 1.260880947113037
# training loss :  0.9282272841821435
# Finish epoch 29, time elapsed 172.1740162372589
# Validation loss after epoch 29, , loss: 0.8434621820449829
# Accuracy on val after epoch 29, accuracy: 82.39233532835081
# IOU for class 11 on val after epoch29, iou: 58.03110389363078
# IOU for class 20 on val after epoch29, iou: 13.195794068881566
# IOU for class 24 on val after epoch29, iou: 13.960546946855755
# IOU for class 26 on val after epoch29, iou: 49.14711929162943
# IOU for class 33 on val after epoch29, iou: 0.00797919330355701
# epoch30, iter0, loss: 0.6951252818107605
